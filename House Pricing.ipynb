# %%
import numpy as np 
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.model_selection import StratifiedShuffleSplit, KFold, GridSearchCV
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, mean_absolute_error

from sklearn.linear_model import Lasso, Ridge, SGDRegressor
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
import xgboost as xgb
import lightgbm as lgb

import explore_data as exp  # all function to quickly explore the data

import warnings

pd.set_option('max_columns', 200)

# %%
# %matplotlib inline
os.chdir('C:\\Users\\haju1\\OneDrive\\Documents\\COURS\\Cours 3A\\Testetprojets\\House pricing')
train = pd.read_csv('train.csv')
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %%
train.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
#                   ...
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# KitchenQual       object
# TotRmsAbvGrd       int64
# Functional        object
# Fireplaces         int64
# FireplaceQu       object
# GarageType        object
# GarageYrBlt      float64
# GarageFinish      object
# GarageCars         int64
# GarageArea         int64
# GarageQual        object
# GarageCond        object
# PavedDrive        object
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# PoolQC            object
# Fence             object
# MiscFeature       object
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# target           float64
# Length: 81, dtype: object

# %%
col_mis = exp.list_missing(train)
# Out:
# Column LotFrontage: 17.74% missing
# Column Alley: 93.77% missing
# Column MasVnrType: 0.55% missing
# Column MasVnrArea: 0.55% missing
# Column BsmtQual: 2.53% missing
# Column BsmtCond: 2.53% missing
# Column BsmtExposure: 2.6% missing
# Column BsmtFinType1: 2.53% missing
# Column BsmtFinType2: 2.6% missing
# Column Electrical: 0.07% missing
# Column FireplaceQu: 47.26% missing
# Column GarageType: 5.55% missing
# Column GarageYrBlt: 5.55% missing
# Column GarageFinish: 5.55% missing
# Column GarageQual: 5.55% missing
# Column GarageCond: 5.55% missing
# Column PoolQC: 99.52% missing
# Column Fence: 80.75% missing
# Column MiscFeature: 96.3% missing

# %%
train.hist(bins = 50,figsize=(20,15))
plt.show()

# %%
train['target'] = np.log1p(train.SalePrice)
del train['SalePrice']
train.loc[:,'target'].hist()

# %%
train = train[train.GrLivArea < 4500].reset_index(drop=True)

# %%
def make_test(train, test_size, random_state, strat_feat=None):
    if strat_feat:
        
        split = StratifiedShuffleSplit(n_splits=1, test_size=test_size, random_state=random_state)

        for train_index, test_index in split.split(train, train[strat_feat]):
            train_set = train.loc[train_index]
            test_set = train.loc[test_index]
            
    return train_set, test_set

# %%
train_set,test_set = make_test(train, test_size = 0.2, random_state = 42,strat_feat = 'Neighborhood')

# %%
class general_cleaner(BaseEstimator, TransformerMixin):
    '''
    This class applies what we know from the documetation.
    It cleans some known missing values
    If flags the missing values

    This process is supposed to happen as first step of any pipeline
    '''
        
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        #LotFrontage
        X.loc[X.LotFrontage.isnull(), 'LotFrontage'] = 0
        #Alley
        X.loc[X.Alley.isnull(), 'Alley'] = "NoAlley"
        #MSSubClass
        X['MSSubClass'] = X['MSSubClass'].astype(str)
        #MissingBasement
        fil = ((X.BsmtQual.isnull()) & (X.BsmtCond.isnull()) & (X.BsmtExposure.isnull()) &
               (X.BsmtFinType1.isnull()) & (X.BsmtFinType2.isnull()))
        fil1 = ((X.BsmtQual.notnull()) | (X.BsmtCond.notnull()) | (X.BsmtExposure.notnull()) |
              (X.BsmtFinType1.notnull()) | (X.BsmtFinType2.notnull()))
        X.loc[fil1, 'MisBsm'] = 0
        X.loc[fil, 'MisBsm'] = 1 # made explicit for safety
        #BsmtQual
        X.loc[fil, 'BsmtQual'] = "NoBsmt" #missing basement
        #BsmtCond
        X.loc[fil, 'BsmtCond'] = "NoBsmt" #missing basement
        #BsmtExposure
        X.loc[fil, 'BsmtExposure'] = "NoBsmt" #missing basement
        #BsmtFinType1
        X.loc[fil, 'BsmtFinType1'] = "NoBsmt" #missing basement
        #BsmtFinType2
        X.loc[fil, 'BsmtFinType2'] = "NoBsmt" #missing basement
        #BsmtFinSF1
        X.loc[fil, 'BsmtFinSF1'] = 0 # No bsmt
        #BsmtFinSF2
        X.loc[fil, 'BsmtFinSF2'] = 0 # No bsmt
        #BsmtUnfSF
        X.loc[fil, 'BsmtUnfSF'] = 0 # No bsmt
        #TotalBsmtSF
        X.loc[fil, 'TotalBsmtSF'] = 0 # No bsmt
        #BsmtFullBath
        X.loc[fil, 'BsmtFullBath'] = 0 # No bsmt
        #BsmtHalfBath
        X.loc[fil, 'BsmtHalfBath'] = 0 # No bsmt
        #FireplaceQu
        X.loc[(X.Fireplaces == 0) & (X.FireplaceQu.isnull()), 'FireplaceQu'] = "NoFire" #missing
        #MisGarage
        fil = ((X.GarageYrBlt.isnull()) & (X.GarageType.isnull()) & (X.GarageFinish.isnull()) &
              (X.GarageQual.isnull()) & (X.GarageCond.isnull()))
        fil1 = ((X.GarageYrBlt.notnull()) | (X.GarageType.notnull()) | (X.GarageFinish.notnull()) |
              (X.GarageQual.notnull()) | (X.GarageCond.notnull()))
        X.loc[fil1, 'MisGarage'] = 0
        X.loc[fil, 'MisGarage'] = 1
        #GarageYrBlt
        X.loc[X.GarageYrBlt > 2200, 'GarageYrBlt'] = 2007 #correct mistake
        X.loc[fil, 'GarageYrBlt'] = X['YearBuilt']  # if no garage, use the age of the building
        #GarageType
        X.loc[fil, 'GarageType'] = "NoGrg" #missing garage
        #GarageFinish
        X.loc[fil, 'GarageFinish'] = "NoGrg" #missing
        #GarageQual
        X.loc[fil, 'GarageQual'] = "NoGrg" #missing
        #GarageCond
        X.loc[fil, 'GarageCond'] = "NoGrg" #missing
        #Fence
        X.loc[X.Fence.isnull(), 'Fence'] = "NoFence" #missing fence
        #Pool
        fil = ((X.PoolArea == 0) & (X.PoolQC.isnull()))
        X.loc[fil, 'PoolQC'] = 'NoPool' 
        
        del X['Id']
        del X['MiscFeature']  # we already know it doesn't matter
        return X

# %%
train_cleaned = train_set.copy()  # I want to work on train_set again later from scratch

train_cleaned = general_cleaner().fit_transform(train_cleaned)

mis_cols = exp.list_missing(train_cleaned)
# Out:
# Column MasVnrType: 0.69% missing
# Column MasVnrArea: 0.69% missing
# Column BsmtExposure: 0.09% missing
# Column BsmtFinType2: 0.09% missing
# Column Electrical: 0.09% missing

# %%
high_corr = exp.plot_correlations(train_cleaned, 'target', limit=10, annot=True)

# %%
high_corr = exp.plot_correlations(train_cleaned, 'target', limit=20)

# %%
for col in high_corr[1:10].index:
    exp.plot_distribution(train_cleaned, col, correlation=high_corr)

# %%
exp.corr_target(train_cleaned, 'target', list(high_corr[1:12].index))
# Out:
#               OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  \
# OverallQual      1.000000   0.585816    0.598033    0.562526     0.539522
# GrLivArea        0.585816   1.000000    0.478804    0.464773     0.415985
# GarageCars       0.598033   0.478804    1.000000    0.890761     0.446050
# GarageArea       0.562526   0.464773    0.890761    1.000000     0.477320
# TotalBsmtSF      0.539522   0.415985    0.446050    0.477320     1.000000
# 1stFlrSF         0.468888   0.544177    0.447635    0.488478     0.806632
# FullBath         0.549292   0.657008    0.467338    0.414973     0.325399
# YearBuilt        0.577346   0.202665    0.535189    0.483811     0.388906
# YearRemodAdd     0.560038   0.286608    0.422245    0.377897     0.280410
# GarageYrBlt      0.556532   0.230727    0.619500    0.606255     0.344956
# TotRmsAbvGrd     0.409438   0.824636    0.357898    0.331771     0.261024
# target           0.819361   0.727299    0.680372    0.661336     0.639993
#
#               1stFlrSF  FullBath  YearBuilt  YearRemodAdd  GarageYrBlt  \
# OverallQual   0.468888  0.549292   0.577346      0.560038     0.556532
# GrLivArea     0.544177  0.657008   0.202665      0.286608     0.230727
# GarageCars    0.447635  0.467338   0.535189      0.422245     0.619500
# GarageArea    0.488478  0.414973   0.483811      0.377897     0.606255
# TotalBsmtSF   0.806632  0.325399   0.388906      0.280410     0.344956
# 1stFlrSF      1.000000  0.401083   0.279176      0.220801     0.266022
# FullBath      0.401083  1.000000   0.456769      0.434522     0.456739
# YearBuilt     0.279176  0.456769   1.000000      0.582960     0.850988
# YearRemodAdd  0.220801  0.434522   0.582960      1.000000     0.607140
# GarageYrBlt   0.266022  0.456739   0.850988      0.607140     1.000000
# TotRmsAbvGrd  0.403418  0.558325   0.087873      0.174101     0.122038
# target        0.621208  0.600808   0.588618      0.569856     0.567486
#
#               TotRmsAbvGrd    target
# OverallQual       0.409438  0.819361
# GrLivArea         0.824636  0.727299
# GarageCars        0.357898  0.680372
# GarageArea        0.331771  0.661336
# TotalBsmtSF       0.261024  0.639993
# 1stFlrSF          0.403418  0.621208
# FullBath          0.558325  0.600808
# YearBuilt         0.087873  0.588618
# YearRemodAdd      0.174101  0.569856
# GarageYrBlt       0.122038  0.567486
# TotRmsAbvGrd      1.000000  0.535980
# target            0.535980  1.000000

# %%
cats = train_cleaned.select_dtypes(exclude = ['float64','int64'])
del cats['MSSubClass']
del cats['Utilities']
cats
# Out:
#      MSZoning Street    Alley LotShape LandContour LotConfig LandSlope  \
# 1201       RM   Pave  NoAlley      Reg         Lvl    Corner       Gtl
# 896        RL   Pave  NoAlley      Reg         Lvl    Inside       Gtl
# 27         RL   Pave  NoAlley      Reg         Lvl    Inside       Gtl
# 993        RL   Pave  NoAlley      Reg         Lvl       FR2       Gtl
# 673        RL   Pave  NoAlley      Reg         Lvl    Inside       Gtl
# 1430       RL   Pave     Grvl      Reg         Lvl    Inside       Gtl
# 796        RL   Pave  NoAlley      Reg         Lvl    Inside       Gtl
# 1231       RL   Pave  NoAlley      Reg         Lvl       FR2       Gtl
# 1277       RL   Pave  NoAlley      Reg         Lvl    Inside       Gtl
# 775        RL   Pave  NoAlley      IR1         Lvl    Inside       Gtl
# 1022       RL   Pave  NoAlley      Reg         Lvl    Inside       Gtl
# 409        FV   Pave  NoAlley      Reg         Lvl    Inside       Gtl
# 1227       RL   Pave  NoAlley      Reg         Lvl    Corner       Gtl
# 690        RL   Pave  NoAlley      IR1         Lvl    Corner       Gtl
# 333        RM   Pave  NoAlley      Reg         Lvl       FR3       Gtl
# 1248       RL   Pave  NoAlley      Reg         Lvl    Inside       Gtl
# 871        RL   Pave  NoAlley      Reg         Lvl    Corner       Gtl
# 649        FV   Pave  NoAlley      Reg         Lvl    Inside       Gtl
# 1349       RL   Pave  NoAlley      IR1         Lvl    Inside       Gtl
# 965        RL   Pave  NoAlley      IR1         HLS    Inside       Gtl
# 1325       RL   Pave  NoAlley      Reg         Lvl    Inside       Gtl
# 150        RL   Pave  NoAlley      Reg         Lvl    Corner       Gtl
# 528        RL   Pave  NoAlley      IR1         Lvl   CulDSac       Gtl
# 840        RM   Pave     Grvl      Reg         Lvl    Inside       Gtl
# 1322       RL   Pave  NoAlley      Reg         Lvl    Inside       Gtl
# 303        RL   Pave  NoAlley      Reg         Lvl    Corner       Gtl
# 706        RL   Pave  NoAlley      Reg         Lvl    Inside       Gtl
# 473        RL   Pave  NoAlley      IR1         Lvl    Inside       Gtl
# 1395       RM   Pave  NoAlley      Reg         Lvl    Inside       Gtl
# 1019       RL   Pave  NoAlley      Reg         Lvl    Inside       Gtl
# ...       ...    ...      ...      ...         ...       ...       ...
# 1229       RL   Pave  NoAlley      IR1         Lvl    Inside       Gtl
# 430        RM   Pave  NoAlley      Reg         Lvl    Inside       Gtl
# 25         RL   Pave  NoAlley      Reg         Lvl    Corner       Gtl
# 830        FV   Pave     Pave      Reg         Lvl    Inside       Gtl
# 272        RL   Pave  NoAlley      IR1         Lvl   CulDSac       Gtl
# 514        RL   Pave  NoAlley      Reg         Lvl    Inside       Gtl
# 61         RM   Pave  NoAlley      Reg         Lvl    Inside       Gtl
# 525        RL   Pave  NoAlley      Reg         Lvl    Inside       Gtl
# 980        RL   Pave  NoAlley      IR1         Lvl    Corner       Gtl
# 1167       RL   Pave  NoAlley      Reg         Lvl    Corner       Gtl
# 944        RM   Pave  NoAlley      Reg         Lvl    Corner       Gtl
# 1373       RL   Pave  NoAlley      IR1         HLS    Inside       Gtl
# 568        RL   Pave  NoAlley      IR1         Lvl    Corner       Gtl
# 598        RM   Pave  NoAlley      Reg         Lvl    Inside       Gtl
# 714        RL   Pave  NoAlley      Reg         Lvl    Inside       Gtl
# 354        RL   Pave  NoAlley      Reg         Bnk    Inside       Gtl
# 978        RL   Pave  NoAlley      Reg         Lvl    Corner       Gtl
# 842        RL   Pave  NoAlley      Reg         Lvl    Corner       Gtl
# 760        RM   Pave  NoAlley      Reg         Lvl       FR2       Gtl
# 707        RL   Pave  NoAlley      IR1         Lvl    Inside       Gtl
# 49         RL   Pave  NoAlley      Reg         Lvl    Inside       Gtl
# 1336       RL   Pave  NoAlley      IR1         Lvl    Corner       Gtl
# 1214       RL   Pave  NoAlley      IR1         Lvl    Inside       Gtl
# 740        RL   Pave  NoAlley      IR1         Lvl    Inside       Gtl
# 20         RL   Pave  NoAlley      IR1         Lvl    Corner       Gtl
# 651        RL   Pave  NoAlley      Reg         Lvl    Inside       Gtl
# 719        RL   Pave  NoAlley      IR1         Low   CulDSac       Mod
# 1439       RM   Pave  NoAlley      Reg         Lvl    Inside       Gtl
# 1423       RL   Pave  NoAlley      IR1         Lvl    Inside       Gtl
# 280        RL   Pave  NoAlley      Reg         Lvl    Inside       Gtl
#
#      Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle  \
# 1201      BrkSide       Norm       Norm     1Fam     1.5Fin     Gable
# 896       SawyerW      Feedr       Norm   Duplex     2Story     Gable
# 27        NridgHt       Norm       Norm     1Fam     1Story     Gable
# 993       NridgHt       Norm       Norm     1Fam     1Story       Hip
# 673         NAmes       Norm       Norm     1Fam     1Story     Gable
# 1430      OldTown       Norm       Norm     1Fam     1Story     Gable
# 796         NAmes       Norm       Norm     1Fam     1Story     Gable
# 1231        NAmes       Norm       Norm   Duplex     1Story     Gable
# 1277      CollgCr       Norm       Norm     1Fam     2Story     Gable
# 775       CollgCr       Norm       Norm     1Fam     1Story     Gable
# 1022      Blmngtn       Norm       Norm   TwnhsE     1Story     Gable
# 409       Somerst       Norm       Norm     1Fam     2Story     Gable
# 1227      NridgHt       Norm       Norm   TwnhsE     1Story       Hip
# 690       NoRidge       Norm       Norm     1Fam     2Story     Gable
# 333       NridgHt       Norm       Norm   TwnhsE     1Story     Gable
# 1248        NAmes       Norm       Norm     1Fam     1Story     Gable
# 871         NAmes       Norm       Norm     1Fam     1Story     Gable
# 649       Somerst       Norm       Norm     1Fam     2Story     Gable
# 1349        NAmes       Norm       Norm     1Fam     2Story     Gable
# 965       Crawfor       Norm       Norm     1Fam     1.5Fin     Gable
# 1325      Mitchel       Norm       Norm     1Fam     1Story     Gable
# 150       CollgCr       Norm       Norm     1Fam     1Story     Gable
# 528       Crawfor       Norm       Norm     1Fam     1Story       Hip
# 840       OldTown       Norm       Norm     1Fam     2Story     Gable
# 1322      Somerst       Norm       Norm     1Fam     1Story     Gable
# 303       CollgCr       Norm       Norm     1Fam     1Story     Gable
# 706       NridgHt       Norm       Norm   TwnhsE     1Story       Hip
# 473       NridgHt       Norm       Norm     1Fam     1Story     Gable
# 1395      BrkSide       Norm       Norm     1Fam     2Story     Gable
# 1019      Edwards       Norm       Norm     1Fam     1Story     Gable
# ...           ...        ...        ...      ...        ...       ...
# 1229       Sawyer      Feedr       RRAe   Duplex     1.5Fin      Shed
# 430        BrDale       Norm       Norm    Twnhs     2Story     Gable
# 25        NridgHt       Norm       Norm     1Fam     1Story     Gable
# 830       Somerst       Norm       Norm   TwnhsE     2Story     Gable
# 272       NoRidge       Norm       Norm     1Fam     2Story     Gable
# 514       Crawfor       Norm       Norm     1Fam     1.5Unf     Gable
# 61         IDOTRR       Norm       Norm     1Fam     2.5Unf     Gable
# 525         NAmes       Norm       Norm     1Fam     1Story       Hip
# 980       NoRidge       Norm       Norm     1Fam     2Story       Hip
# 1167      Edwards       Norm       Norm     1Fam     2Story       Hip
# 944       OldTown       Norm       Norm     1Fam     1.5Fin       Hip
# 1373       Timber       Norm       Norm     1Fam     1Story     Gable
# 568         NAmes       Norm       Norm   Duplex     SFoyer     Gable
# 598       Blueste       Norm       Norm    Twnhs     2Story     Gable
# 714        NWAmes       Norm       Norm     1Fam     1Story       Hip
# 354         SWISU       Norm       Norm     1Fam     1.5Fin     Gable
# 978        Sawyer      Feedr       Norm     1Fam     1Story     Gable
# 842         NAmes     Artery       Norm   Duplex     1Story     Gable
# 760       BrkSide      Feedr       Norm     1Fam     1Story     Gable
# 707       Gilbert       Norm       Norm     1Fam     2Story       Hip
# 49         Sawyer       Norm       Norm     1Fam     1Story     Gable
# 1336      CollgCr       Norm       Norm     1Fam     2Story     Gable
# 1214       Sawyer       Norm       Norm     1Fam     1Story     Gable
# 740        Sawyer      Feedr       Norm     1Fam     1Story       Hip
# 20        NridgHt       Norm       Norm     1Fam     2Story     Gable
# 651       CollgCr       Norm       Norm     1Fam     2Story     Gable
# 719       StoneBr       Norm       Norm     1Fam     1Story     Gable
# 1439      CollgCr       Norm       Norm   TwnhsE     1Story     Gable
# 1423        NAmes       Norm       Norm     1Fam     1Story       Hip
# 280       SawyerW       Norm       Norm     1Fam     2Story     Gable
#
#      RoofMatl Exterior1st Exterior2nd MasVnrType ExterQual ExterCond  \
# 1201  CompShg     Wd Sdng     Wd Sdng       None        TA        TA
# 896   CompShg     Plywood     Plywood       None        TA        TA
# 27    CompShg     VinylSd     VinylSd      Stone        Gd        TA
# 993   CompShg     CemntBd     CmentBd      Stone        Ex        TA
# 673   CompShg     HdBoard     HdBoard       None        TA        TA
# 1430  CompShg     Wd Sdng     Wd Sdng       None        TA        TA
# 796   CompShg     VinylSd     VinylSd       None        TA        TA
# 1231  CompShg     HdBoard     HdBoard       None        TA        TA
# 1277  CompShg     VinylSd     VinylSd        NaN        Gd        TA
# 775   CompShg     VinylSd     VinylSd    BrkFace        Gd        TA
# 1022  CompShg     VinylSd     VinylSd    BrkFace        Gd        TA
# 409   CompShg     VinylSd     VinylSd      Stone        Gd        TA
# 1227  CompShg     MetalSd     MetalSd    BrkFace        Ex        TA
# 690   WdShngl     HdBoard     HdBoard    BrkFace        Ex        TA
# 333   CompShg     VinylSd     VinylSd      Stone        Gd        TA
# 1248  CompShg     MetalSd     MetalSd       None        TA        TA
# 871   CompShg     WdShing     Wd Shng       None        Gd        TA
# 649   CompShg     CemntBd     CmentBd        NaN        Gd        TA
# 1349  CompShg     HdBoard     HdBoard    BrkFace        TA        TA
# 965   CompShg     MetalSd     MetalSd       None        Gd        Gd
# 1325  CompShg     VinylSd     VinylSd       None        Gd        Gd
# 150   CompShg     HdBoard     HdBoard       None        TA        TA
# 528   CompShg     Wd Sdng       Stone        NaN        Gd        TA
# 840   CompShg     MetalSd     MetalSd       None        TA        TA
# 1322  CompShg     VinylSd     VinylSd    BrkFace        Gd        TA
# 303   CompShg     VinylSd     VinylSd       None        TA        TA
# 706   CompShg     MetalSd     MetalSd    BrkFace        Gd        TA
# 473   CompShg     VinylSd     VinylSd    BrkFace        Gd        TA
# 1395  CompShg     MetalSd     MetalSd       None        TA        TA
# 1019  CompShg     VinylSd     VinylSd       None        TA        TA
# ...       ...         ...         ...        ...       ...       ...
# 1229  CompShg     Plywood     Plywood       None        TA        TA
# 430   CompShg     HdBoard     HdBoard    BrkFace        TA        TA
# 25    CompShg     VinylSd     VinylSd      Stone        Gd        TA
# 830   CompShg     MetalSd     MetalSd       None        TA        TA
# 272   CompShg     VinylSd     VinylSd    BrkFace        Gd        TA
# 514   CompShg     Wd Sdng     Wd Sdng       None        TA        TA
# 61    CompShg     MetalSd     MetalSd       None        TA        TA
# 525   CompShg     Wd Sdng     Wd Sdng       None        TA        TA
# 980   CompShg     VinylSd     VinylSd    BrkFace        Gd        TA
# 1167  CompShg      Stucco      Stucco       None        TA        TA
# 944   CompShg     VinylSd     VinylSd       None        TA        TA
# 1373  CompShg     VinylSd     VinylSd    BrkFace        Gd        TA
# 568   CompShg     MetalSd     MetalSd       None        TA        TA
# 598   CompShg     MetalSd     MetalSd       None        TA        Gd
# 714   CompShg     HdBoard     HdBoard    BrkFace        TA        TA
# 354   CompShg     Wd Sdng     MetalSd       None        TA        TA
# 978   CompShg     VinylSd     VinylSd       None        TA        TA
# 842   CompShg     BrkFace     BrkFace       None        TA        TA
# 760   CompShg     Wd Sdng     Wd Sdng       None        TA        TA
# 707   CompShg     VinylSd     VinylSd       None        Gd        TA
# 49    CompShg     HdBoard     HdBoard       None        TA        TA
# 1336  CompShg     VinylSd     VinylSd       None        Gd        TA
# 1214  CompShg     VinylSd     VinylSd       None        TA        TA
# 740   CompShg     HdBoard     HdBoard       None        TA        Gd
# 20    CompShg     VinylSd     VinylSd    BrkFace        Gd        TA
# 651   CompShg     VinylSd     VinylSd       None        Gd        TA
# 719   CompShg     HdBoard     HdBoard       None        Gd        TA
# 1439  CompShg     VinylSd     VinylSd    BrkFace        Gd        TA
# 1423  CompShg     HdBoard     HdBoard      Stone        Gd        TA
# 280   CompShg     Plywood     Plywood    BrkFace        Gd        TA
#
#      Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2  \
# 1201     BrkTil       TA       TA           No          Unf          Unf
# 896        Slab   NoBsmt   NoBsmt       NoBsmt       NoBsmt       NoBsmt
# 27        PConc       Ex       TA           No          GLQ          Unf
# 993       PConc       Ex       TA           Gd          GLQ          Unf
# 673      CBlock       TA       TA           No          Rec          Unf
# 1430     BrkTil       TA       TA           No          Unf          Unf
# 796      CBlock       TA       TA           No          BLQ          Unf
# 1231       Slab   NoBsmt   NoBsmt       NoBsmt       NoBsmt       NoBsmt
# 1277      PConc       Gd       TA           No          GLQ          Unf
# 775       PConc       Gd       TA           Av          GLQ          Unf
# 1022      PConc       Gd       Gd           No          GLQ          Unf
# 409       PConc       Ex       TA           No          GLQ          Unf
# 1227      PConc       Ex       TA           No          GLQ          Unf
# 690       PConc       Ex       TA           Gd          GLQ          Unf
# 333       PConc       Gd       TA           Av          GLQ          Unf
# 1248     CBlock       TA       TA           No          BLQ          Rec
# 871       Stone       TA       TA           Av          Unf          Unf
# 649       PConc       Gd       TA           No          Unf          Unf
# 1349     CBlock       TA       TA           No          Rec          Unf
# 965      BrkTil       TA       Fa           No          Rec          Unf
# 1325     CBlock       TA       TA           No          ALQ          Unf
# 150      CBlock       TA       TA           Av          BLQ          Unf
# 528       PConc       TA       TA           No          Rec          Unf
# 840       PConc       TA       TA           No          Unf          Unf
# 1322      PConc       Ex       TA           Av          Unf          Unf
# 303       PConc       TA       TA           No          ALQ          Unf
# 706       PConc       Gd       TA           No          GLQ          Unf
# 473       PConc       Ex       TA           Gd          GLQ          Unf
# 1395     BrkTil       TA       TA           Mn          Unf          Unf
# 1019      PConc       Gd       TA           No          GLQ          Unf
# ...         ...      ...      ...          ...          ...          ...
# 1229     CBlock       Gd       TA           No          GLQ          Rec
# 430      CBlock       TA       TA           No          ALQ          Unf
# 25        PConc       Gd       TA           No          Unf          Unf
# 830       PConc       Gd       TA           No          Unf          Unf
# 272       PConc       Gd       TA           No          GLQ          Unf
# 514      BrkTil       TA       TA           No          Unf          Unf
# 61       BrkTil       TA       Fa           No          Unf          Unf
# 525      CBlock       Gd       TA           No          Rec          Unf
# 980       PConc       Gd       TA           No          GLQ          Unf
# 1167     CBlock       TA       TA           No          Rec          Unf
# 944      BrkTil       TA       TA           No          LwQ          Unf
# 1373      PConc       Gd       TA           Gd          Unf          Unf
# 568      CBlock       Gd       TA           Gd          GLQ          Unf
# 598      CBlock       Gd       TA           No          LwQ          GLQ
# 714      CBlock       Gd       TA           No          Unf          Unf
# 354      CBlock       TA       TA           No          LwQ          Unf
# 978       PConc       TA       TA           No          Rec          Unf
# 842      CBlock       TA       TA           No          Unf          Unf
# 760       PConc       TA       TA           Mn          LwQ          Unf
# 707       PConc       Gd       TA           Av          Unf          Unf
# 49       CBlock       TA       TA           No          BLQ          Unf
# 1336      PConc       Gd       TA           No          GLQ          Unf
# 1214     CBlock       TA       TA           No          Rec          LwQ
# 740      CBlock       TA       TA           Mn          GLQ          Unf
# 20        PConc       Ex       TA           Av          Unf          Unf
# 651       PConc       Gd       TA           No          Unf          Unf
# 719       PConc       Gd       TA           Gd          GLQ          Unf
# 1439      PConc       Gd       TA           Av          GLQ          Unf
# 1423     CBlock       TA       TA           No          Unf          Unf
# 280      CBlock       Gd       TA           Av          GLQ          Unf
#
#      Heating HeatingQC CentralAir Electrical KitchenQual Functional  \
# 1201    GasA        Ex          Y      SBrkr          TA        Typ
# 896     GasA        TA          Y      SBrkr          TA        Typ
# 27      GasA        Ex          Y      SBrkr          Gd        Typ
# 993     GasA        Ex          Y      SBrkr          Ex        Typ
# 673     GasA        TA          Y      SBrkr          TA        Typ
# 1430    GasA        TA          Y      SBrkr          TA        Typ
# 796     GasA        Gd          Y      SBrkr          TA        Typ
# 1231    GasA        TA          Y      SBrkr          TA        Typ
# 1277    GasA        Ex          Y      SBrkr          Gd        Typ
# 775     GasA        Ex          Y      SBrkr          Gd        Typ
# 1022    GasA        Ex          Y      SBrkr          Gd        Typ
# 409     GasA        Ex          Y      SBrkr          Ex        Typ
# 1227    GasA        Ex          Y      SBrkr          Ex        Typ
# 690     GasA        Ex          Y      SBrkr          Ex        Typ
# 333     GasA        Ex          Y      SBrkr          Gd        Typ
# 1248    GasA        TA          Y      SBrkr          TA        Typ
# 871     GasA        Gd          Y      SBrkr          Gd        Typ
# 649     GasA        Ex          Y      SBrkr          Gd        Typ
# 1349    GasA        Ex          Y      SBrkr          TA        Typ
# 965     GasA        Ex          Y      SBrkr          TA       Min2
# 1325    GasA        Ex          Y      SBrkr          Gd        Typ
# 150     GasA        TA          Y      SBrkr          TA        Typ
# 528     GasA        TA          Y      SBrkr          TA       Maj1
# 840     GasA        Gd          Y      SBrkr          Gd        Typ
# 1322    GasA        Ex          Y      SBrkr          Gd        Typ
# 303     GasA        TA          Y      SBrkr          TA        Typ
# 706     GasA        Ex          Y      SBrkr          Gd        Typ
# 473     GasA        Ex          Y      SBrkr          Gd        Typ
# 1395    GasA        Ex          Y      SBrkr          TA        Typ
# 1019    GasA        Ex          Y      SBrkr          Gd        Typ
# ...      ...       ...        ...        ...         ...        ...
# 1229    GasA        Ex          Y      SBrkr          TA        Typ
# 430     GasA        TA          Y      SBrkr          TA        Typ
# 25      GasA        Ex          Y      SBrkr          Gd        Typ
# 830     GasA        Ex          Y      SBrkr          Gd        Typ
# 272     GasA        Ex          Y      SBrkr          Gd        Typ
# 514     Grav        Fa          N      SBrkr          TA        Typ
# 61      GasA        TA          N      SBrkr          Fa        Typ
# 525     GasA        TA          Y      SBrkr          TA        Typ
# 980     GasA        Ex          Y      SBrkr          Gd        Typ
# 1167    GasA        Ex          Y      SBrkr          Gd        Typ
# 944     GasA        TA          Y      SBrkr          TA        Typ
# 1373    GasA        Ex          Y      SBrkr          Gd        Typ
# 568     GasA        TA          Y      SBrkr          TA        Typ
# 598     GasA        TA          Y      SBrkr          TA        Typ
# 714     GasA        TA          Y      SBrkr          TA        Typ
# 354     GasA        Ex          Y      SBrkr          TA        Typ
# 978     GasA        TA          Y      SBrkr          TA        Typ
# 842     GasA        Ex          N      SBrkr          TA        Typ
# 760     GasA        TA          Y      SBrkr          Fa       Min1
# 707     GasA        Ex          Y      SBrkr          Gd        Typ
# 49      GasA        Ex          Y      SBrkr          TA        Typ
# 1336    GasA        Ex          Y      SBrkr          Gd        Typ
# 1214    GasA        TA          Y      SBrkr          TA        Typ
# 740     GasA        Gd          Y      SBrkr          Gd        Typ
# 20      GasA        Ex          Y      SBrkr          Gd        Typ
# 651     GasA        Ex          Y      SBrkr          Gd        Typ
# 719     GasA        TA          Y      SBrkr          Gd        Typ
# 1439    GasA        Ex          Y      SBrkr          Gd        Typ
# 1423    GasA        Ex          Y      SBrkr          Gd        Typ
# 280     GasA        Gd          Y      SBrkr          Gd        Typ
#
#      FireplaceQu GarageType GarageFinish GarageQual GarageCond PavedDrive  \
# 1201          Fa     Detchd          Unf         TA         TA          N
# 896       NoFire     Detchd          Unf         TA         TA          Y
# 27            Gd     Attchd          RFn         TA         TA          Y
# 993           Gd     Attchd          Fin         TA         TA          Y
# 673           Gd     Attchd          RFn         TA         TA          Y
# 1430      NoFire     Detchd          Unf         Fa         Fa          Y
# 796       NoFire     Attchd          Unf         TA         TA          Y
# 1231      NoFire    CarPort          Unf         TA         TA          Y
# 1277          Gd     Attchd          RFn         TA         TA          Y
# 775       NoFire     Attchd          RFn         TA         TA          Y
# 1022          Gd     Attchd          Fin         TA         TA          Y
# 409           Gd     Attchd          Fin         TA         TA          Y
# 1227          Gd     Attchd          Fin         TA         TA          Y
# 690           Ex     Attchd          Fin         TA         TA          Y
# 333           Gd     Attchd          RFn         TA         TA          Y
# 1248      NoFire     Attchd          Unf         TA         TA          Y
# 871       NoFire     Attchd          Unf         TA         TA          Y
# 649       NoFire     Attchd          RFn         TA         TA          Y
# 1349          Gd     Attchd          Fin         TA         TA          Y
# 965           TA     Detchd          Unf         TA         TA          Y
# 1325          Ex     Attchd          Unf         TA         TA          Y
# 150       NoFire     Attchd          Unf         TA         TA          Y
# 528           TA     Attchd          RFn         TA         TA          Y
# 840           Po     Detchd          Unf         Gd         TA          P
# 1322          Gd     Attchd          RFn         TA         TA          Y
# 303       NoFire     Attchd          Unf         TA         TA          Y
# 706           Gd     Attchd          Fin         TA         TA          Y
# 473           Ex     Attchd          RFn         TA         TA          Y
# 1395      NoFire     Detchd          Unf         Fa         Fa          N
# 1019      NoFire     Attchd          Fin         TA         TA          Y
# ...          ...        ...          ...        ...        ...        ...
# 1229          TA    BuiltIn          RFn         TA         TA          N
# 430       NoFire     Detchd          Unf         TA         TA          Y
# 25            Gd     Attchd          RFn         TA         TA          Y
# 830       NoFire     Detchd          RFn         TA         TA          Y
# 272           Gd     Attchd          Fin         TA         TA          Y
# 514       NoFire     Detchd          Unf         Po         Po          Y
# 61        NoFire     Detchd          Unf         TA         TA          N
# 525       NoFire     Attchd          Unf         TA         TA          Y
# 980           TA     Attchd          Fin         TA         TA          Y
# 1167          TA    Basment          Unf         TA         TA          Y
# 944       NoFire     Detchd          Unf         TA         TA          Y
# 1373          Gd     Attchd          Fin         TA         TA          Y
# 568           TA     Detchd          Unf         TA         TA          Y
# 598           TA     Attchd          Fin         TA         TA          Y
# 714           TA     Attchd          RFn         TA         TA          Y
# 354           Gd     Attchd          Unf         TA         TA          Y
# 978       NoFire     Detchd          Unf         TA         TA          Y
# 842       NoFire      NoGrg        NoGrg      NoGrg      NoGrg          Y
# 760       NoFire     Detchd          Unf         TA         TA          Y
# 707           Gd     Attchd          Fin         TA         TA          Y
# 49        NoFire     Attchd          Unf         TA         TA          Y
# 1336      NoFire    BuiltIn          RFn         TA         TA          Y
# 1214      NoFire     Detchd          RFn         TA         TA          Y
# 740       NoFire     Detchd          Unf         TA         TA          Y
# 20            Gd    BuiltIn          RFn         TA         TA          Y
# 651           TA     Attchd          RFn         TA         TA          Y
# 719           TA     Attchd          RFn         TA         TA          Y
# 1439          TA     Attchd          RFn         TA         TA          Y
# 1423      NoFire     Detchd          Unf         TA         TA          Y
# 280           TA     Attchd          Fin         TA         TA          Y
#
#       PoolQC    Fence SaleType SaleCondition
# 1201  NoPool  NoFence       WD        Normal
# 896   NoPool  NoFence       WD        Alloca
# 27    NoPool  NoFence       WD        Normal
# 993   NoPool  NoFence       WD        Normal
# 673   NoPool  NoFence       WD        Normal
# 1430  NoPool  NoFence       WD        Normal
# 796   NoPool  NoFence       WD       Abnorml
# 1231  NoPool  NoFence       WD        Normal
# 1277  NoPool  NoFence       WD        Normal
# 775   NoPool  NoFence      New       Partial
# 1022  NoPool  NoFence       WD        Normal
# 409   NoPool  NoFence      New       Partial
# 1227  NoPool  NoFence      New       Partial
# 690   NoPool  NoFence       WD        Normal
# 333   NoPool  NoFence       WD        Normal
# 1248  NoPool  NoFence       WD        Normal
# 871   NoPool     GdWo       WD        Normal
# 649   NoPool  NoFence       WD        Normal
# 1349  NoPool  NoFence       WD        Normal
# 965   NoPool  NoFence       WD        Normal
# 1325  NoPool    MnPrv       WD        Normal
# 150   NoPool    MnPrv       WD        Normal
# 528   NoPool  NoFence       WD        Alloca
# 840   NoPool  NoFence       WD        Normal
# 1322  NoPool  NoFence      New       Partial
# 303   NoPool     GdWo       WD       Abnorml
# 706   NoPool  NoFence       WD        Normal
# 473   NoPool  NoFence      New       Partial
# 1395  NoPool  NoFence       WD        Normal
# 1019  NoPool  NoFence       WD        Normal
# ...      ...      ...      ...           ...
# 1229  NoPool  NoFence       WD        Normal
# 430   NoPool  NoFence      COD       Abnorml
# 25    NoPool  NoFence       WD        Normal
# 830   NoPool  NoFence       WD        Normal
# 272   NoPool  NoFence       WD        Normal
# 514   NoPool    MnPrv       WD        Normal
# 61    NoPool  NoFence       WD        Normal
# 525   NoPool  NoFence       WD        Normal
# 980   NoPool  NoFence       WD        Normal
# 1167  NoPool  NoFence       WD        Normal
# 944   NoPool     MnWw       WD        Normal
# 1373  NoPool  NoFence      New       Partial
# 568   NoPool  NoFence       WD        Normal
# 598   NoPool    GdPrv      COD        Normal
# 714   NoPool    MnPrv       WD        Normal
# 354   NoPool  NoFence       WD        Normal
# 978   NoPool    MnPrv       WD        Normal
# 842   NoPool  NoFence       WD        Normal
# 760   NoPool  NoFence       WD        Normal
# 707   NoPool  NoFence      New       Partial
# 49    NoPool    MnPrv       WD        Normal
# 1336  NoPool  NoFence       WD        Normal
# 1214  NoPool    MnPrv       WD        Normal
# 740   NoPool    GdPrv       WD        Normal
# 20    NoPool  NoFence      New       Partial
# 651   NoPool  NoFence       WD        Normal
# 719   NoPool  NoFence       WD        Normal
# 1439  NoPool  NoFence       WD        Normal
# 1423  NoPool  NoFence       WD        Normal
# 280   NoPool  NoFence       WD        Normal
#
# [1166 rows x 41 columns]

# %%
for cat in cats : 
    exp.segm_target(train_cleaned, cat, 'target')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-114-88a192a62e30> in <module>()
#       1 for cat in cats :
# ----> 2     exp.segm_target(train_cleaned, cat, 'target')
#
# c:\users\haju1\appdata\local\programs\python\python36\lib\explore_data.py in segm_target(data, cat, target)
#     143         sns.distplot(tmp[target], hist=False, kde=True,
#     144                  kde_kws = {'linewidth': 3},
# --> 145                  label = val, ax=ax[1])
#     146     return df
#
# c:\users\haju1\appdata\local\programs\python\python36\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     229     if kde:
#     230         kde_color = kde_kws.pop("color", color)
# --> 231         kdeplot(a, vertical=vertical, ax=ax, color=kde_color, **kde_kws)
#     232         if kde_color != color:
#     233             kde_kws["color"] = kde_color
#
# c:\users\haju1\appdata\local\programs\python\python36\lib\site-packages\seaborn\distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     689         ax = _univariate_kdeplot(data, shade, vertical, kernel, bw,
#     690                                  gridsize, cut, clip, legend, ax,
# --> 691                                  cumulative=cumulative, **kwargs)
#     692
#     693     return ax
#
# c:\users\haju1\appdata\local\programs\python\python36\lib\site-packages\seaborn\distributions.py in _univariate_kdeplot(data, shade, vertical, kernel, bw, gridsize, cut, clip, legend, ax, cumulative, **kwargs)
#     292                               "only implemented in statsmodels."
#     293                               "Please install statsmodels.")
# --> 294         x, y = _scipy_univariate_kde(data, bw, gridsize, cut, clip)
#     295
#     296     # Make sure the density is nonnegative
#
# c:\users\haju1\appdata\local\programs\python\python36\lib\site-packages\seaborn\distributions.py in _scipy_univariate_kde(data, bw, gridsize, cut, clip)
#     364     """Compute a univariate kernel density estimate using scipy."""
#     365     try:
# --> 366         kde = stats.gaussian_kde(data, bw_method=bw)
#     367     except TypeError:
#     368         kde = stats.gaussian_kde(data)
#
# c:\users\haju1\appdata\local\programs\python\python36\lib\site-packages\scipy\stats\kde.py in __init__(self, dataset, bw_method)
#     167         self.dataset = atleast_2d(dataset)
#     168         if not self.dataset.size > 1:
# --> 169             raise ValueError("`dataset` input should have multiple elements.")
#     170
#     171         self.d, self.n = self.dataset.shape
#
# ValueError: `dataset` input should have multiple elements.
